# %%
#https://medium.com/@deepeshrishu09/automatic-image-captioning-with-pytorch-cf576c98d319
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/OMSCS/DL/GroupAssignment/DLGroupProject_ImageCaptioning'

# !pip install -r requirements.txt

#!python -m spacy download en
#!python -m spacy download de
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/OMSCS/DL/GroupAssignment/DLGroupProject_ImageCaptioning
# ...
